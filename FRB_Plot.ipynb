# %% [markdown]
# <a href="https://colab.research.google.com/github/am610/FRB/blob/master/FRB_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import integrate
from scipy.optimize import least_squares, curve_fit
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator)  
from mpl_toolkits.axes_grid1 import make_axes_locatable
import io
from google.colab import files

plt.rc('xtick', labelsize=10) 
plt.rc('ytick', labelsize=10) 
plt.rcParams.update({'font.size': 10})
#plt.rcParams['figure.figsize'] = [20,10] # Use this to change the plot size

# %%
import matplotlib.pyplot as plt

def get_cmap(n, name='hsv'):
    '''Returns a function that maps each index in 0, 1, ..., n-1 to a distinct 
    RGB color; the keyword argument name must be a standard mpl colormap name.'''
    return plt.cm.get_cmap(name, n)
def main():
    N = 100
    fig=plt.figure()
    ax=fig.add_subplot(111)   
    plt.axis('scaled')
    ax.set_xlim([ 0, N])
    ax.set_ylim([-0.5, 0.5])
    cmap = get_cmap(N)
    for i in range(N):
        rect = plt.Rectangle((i, -0.5), 1, 1, facecolor=cmap(i))
        ax.add_artist(rect)
    ax.set_yticks([])
    plt.show()

if __name__=='__main__':
    main()

# %% [markdown]
# ## 1000

# %%
u1000_1=files.upload()
# Out:
#      <input type="file" id="files-292c4c9c-9417-450a-b8a4-65c3cf3e0c0d" name="files[]" multiple disabled />
#      <output id="result-292c4c9c-9417-450a-b8a4-65c3cf3e0c0d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving p_mean__v2_1000.csv to p_mean__v2_1000 (1).csv

# %%
p_mean_1000 = pd.read_csv(io.BytesIO(u1000_1['p_mean__v2_1000.csv']),delimiter=',')

# %%
cmaps = [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg',
            'gist_rainbow', 'rainbow', 'jet', 'nipy_spectral', 'gist_ncar']

# %%
inter = ['none', 'antialiased', 'nearest', 'bilinear', 'bicubic', 
'spline16', 'spline36', 'hanning', 'hamming', 'hermite', 
'kaiser', 'quadric', 'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos']

# %%
yy=np.ones(np.shape(p_mean_1000-1)[0])
xx=(np.array(np.diag(yy)))

# %%
fig, axes = plt.subplots()
#print(np.abs(P_mean-1))
divider = make_axes_locatable(axes)
cax = divider.append_axes('right', size='5%', pad=0.05)
im = axes.imshow(np.abs(p_mean_1000-1), cmap=cmaps[5],interpolation=inter[6],alpha=3)#,alpha=xx)
fig.colorbar(im,cax=cax,  orientation='vertical').ax.set_ylabel('Label')
#plt.imshow(P_std)
plt.tight_layout()
plt.savefig('plot_1000_v2.pdf',bbox_inches='tight')
files.download('plot_1000_v2.pdf')

# %% [markdown]
# ## 100

# %%
u100_1=files.upload()
# Out:
#      <input type="file" id="files-7764ee2e-5e6f-41a8-8940-70593ff0e976" name="files[]" multiple disabled />
#      <output id="result-7764ee2e-5e6f-41a8-8940-70593ff0e976">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving p_mean__v2_100.csv to p_mean__v2_100.csv

# %%
p_mean_100 = pd.read_csv(io.BytesIO(u100_1['p_mean__v2_100.csv']),delimiter=',')

# %%
fig, axes = plt.subplots()
#print(np.abs(P_mean-1))
divider = make_axes_locatable(axes)
cax = divider.append_axes('right', size='5%', pad=0.05)
im = axes.imshow(np.abs(p_mean_100-1),cmap=cmaps[5],interpolation=inter[6],alpha=3)
fig.colorbar(im,cax=cax, orientation='vertical').ax.set_ylabel('Label')
#plt.imshow(P_std)
plt.tight_layout()
plt.tight_layout()
plt.savefig('plot_100_v2.pdf',bbox_inches='tight')
files.download('plot_100_v2.pdf')

# %% [markdown]
# ## 10

# %%
u10_1=files.upload()
# Out:
#      <input type="file" id="files-199d275a-f25f-436a-b21f-a49c7ab86b08" name="files[]" multiple disabled />
#      <output id="result-199d275a-f25f-436a-b21f-a49c7ab86b08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving p_mean__v2_10.csv to p_mean__v2_10.csv

# %%
p_mean_10 = pd.read_csv(io.BytesIO(u10_1['p_mean__v2_10.csv']),delimiter=',')

# %%
fig, axes = plt.subplots()
#print(np.abs(P_mean-1))
divider = make_axes_locatable(axes)
plt.ylabel('Z')
plt.xlabel('Z')
cax = divider.append_axes('right', size='5%', pad=0.05)
im = axes.imshow(np.abs(p_mean_10-1),cmap=cmaps[5],interpolation=inter[11],alpha=3)
fig.colorbar(im,cax=cax, orientation='vertical').ax.set_ylabel('Label')
#plt.imshow(P_std)
plt.tight_layout()
#plt.savefig('plot_10_v2.pdf',bbox_inches='tight')
#files.download('plot_10_v2.pdf')
